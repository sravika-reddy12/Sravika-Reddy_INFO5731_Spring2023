# %% [markdown]
# <a href="https://colab.research.google.com/github/sravika-reddy12/Sravika-Reddy_INFO5731_Spring2023/blob/main/In%20class%20Exercise%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The In-class-exercise ( 40 points)**

# %% [markdown]
# Question1 : Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.(10 points)

# %%
'''
Please write your answer here:
        Question :- 
What is the review of APPLE iPhone 14 (Midnight, 256 GB).
The data required for this study are reviews and ratings from customers who have already purchased, used or are using mobile phones.
 Check reviews using the Flipkart website. This includes product reviews and ratings. 
What is the review for this phone. Do you have positive and negative reviews? 
We can analyze the ratings by looking at the words and rating them on some common words.
A minimum of 1000 reviews is required for result.


Procedures for collecting and storing data:

    *I used the BeautifulSoup library to extract information from a website.
    **I used the class name to extract the ratings and added them to an empty list.
    ***To extract 1000 reviews, each page has 10 reviews,
    ****Generated URLs dynamically by iterating
    *****Then I created a dataframe from the list and converted the dataframe to csv 

'''
# Out:
# '\nPlease write your answer here:\n        Question :- \nWhat is the review of APPLE iPhone 14 (Midnight, 256 GB).\nThe data required for this study are reviews and ratings from customers who have already purchased, used or are using mobile phones.\n Check reviews using the Flipkart website. This includes product reviews and ratings. \nWhat is the review for this phone. Do you have positive and negative reviews? \nWe can analyze the ratings by looking at the words and rating them on some common words.\nA minimum of 1000 reviews is required for result.\n\n\nProcedures for collecting and storing data:\n\n    *I used the BeautifulSoup library to extract information from a website.\n    **I used the class name to extract the ratings and added them to an empty list.\n    ***To extract 1000 reviews, each page has 10 reviews,\n    ****Generated URLs dynamically by iterating\n    *****Then I created a dataframe from the list and converted the dataframe to csv \n\n'

# %% [markdown]
# Question2: Write python code to collect 1000 data samples you discussed above (10 points)

# %%
import requests # start program here
from bs4 import BeautifulSoup
import pandas as DP  # importing
a_txt = []
p_txt = []
for num in range(100):
    link = "https://www.flipkart.com/apple-iphone-14-midnight-256-gb/p/itmdb32e3c997112?pid=MOBGHWFH4H3MMRAA&lid=LSTMOBGHWFH4H3MMRAAO7KNHD&marketplace=FLIPKART&sattr[]=color&sattr[]=storage&st=color" + str(num)
    page = requests.get(link)
    soup = BeautifulSoup(page.text, 'html.parser')
    main_reviews = soup.find_all(class_='_2-N8zT') # Getting the Review Heading by using the class name
    text_reviews = soup.find_all(class_='_3LWZlK _1BLPMq')
    # Iterating from list
    for ele, sub_ele in zip(main_reviews, text_reviews) : 
      #Appending
        a_txt.append(ele.text) 
        p_txt.append(sub_ele.text)
        #Dataframe creation
df = DP.DataFrame(list(zip(a_txt, p_txt)), columns =['Review', 'Rating'])  
#print statement
print("Length of data frame is {0}".format(len(df)))
df
# Out:
# Length of data frame is 1000
#                   Review Rating
# 0              Fabulous!      5
# 1            Good choice      4
# 2    Best in the market!      5
# 3              Must buy!      5
# 4              Fabulous!      5
# ..                   ...    ...
# 995            Must buy!      5
# 996   Highly recommended      5
# 997         Nice product      4
# 998             Terrific      5
# 999       Classy product      5
#
# [1000 rows x 2 columns]

# %% [markdown]
# Question 3 : Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2012-2022).(10 points)
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
import requests
import json

# %%
data = {
    "authors": [],
    "coAuthors": [],
    "externalContentTypes": [],
    "pageSize": 10,
    "publicationTypes": [],
    "queryString": "Machine Learning",
    "requireViewablePdf": False,
    "sort": "relevance",
    "venues": [],
    "yearFilter": None
}

# %%
def information_retreival(x):
    if isinstance(x, list):
        for v in x:
            information_retreival(v)
    elif isinstance(x, dict):
        if 'name' in x:
            authors.append(x['name'])
        else:
            for v in x.values():
                information_retreival(v)

# %%
for item in range(1, 1000):  # increase the range size here to extract more pages
    data['page'] = item
    print(f"{'-' * 36}Extracting Page #{item}{'-' * 36}")
    request = requests.post('https://api.semanticscholar.org/datasets/v1/release/latest', json=data).json()
# Out:
# ------------------------------------Extracting Page #1------------------------------------
# ------------------------------------Extracting Page #2------------------------------------
# ------------------------------------Extracting Page #3------------------------------------
# ------------------------------------Extracting Page #4------------------------------------
# ------------------------------------Extracting Page #5------------------------------------
# ------------------------------------Extracting Page #6------------------------------------
# ------------------------------------Extracting Page #7------------------------------------
# ------------------------------------Extracting Page #8------------------------------------
# ------------------------------------Extracting Page #9------------------------------------
# ------------------------------------Extracting Page #10------------------------------------
# ------------------------------------Extracting Page #11------------------------------------
# ------------------------------------Extracting Page #12------------------------------------
# ------------------------------------Extracting Page #13------------------------------------
# ------------------------------------Extracting Page #14------------------------------------
# ------------------------------------Extracting Page #15------------------------------------
# ------------------------------------Extracting Page #16------------------------------------
# ------------------------------------Extracting Page #17------------------------------------
# ------------------------------------Extracting Page #18------------------------------------
# ------------------------------------Extracting Page #19------------------------------------
# ------------------------------------Extracting Page #20------------------------------------
# ------------------------------------Extracting Page #21------------------------------------
# ------------------------------------Extracting Page #22------------------------------------
# ------------------------------------Extracting Page #23------------------------------------
# ------------------------------------Extracting Page #24------------------------------------
# ------------------------------------Extracting Page #25------------------------------------
# ------------------------------------Extracting Page #26------------------------------------
# ------------------------------------Extracting Page #27------------------------------------
# ------------------------------------Extracting Page #28------------------------------------
# ------------------------------------Extracting Page #29------------------------------------
# ------------------------------------Extracting Page #30------------------------------------
# ------------------------------------Extracting Page #31------------------------------------
# ------------------------------------Extracting Page #32------------------------------------
# ------------------------------------Extracting Page #33------------------------------------
# ------------------------------------Extracting Page #34------------------------------------
# ------------------------------------Extracting Page #35------------------------------------
# ------------------------------------Extracting Page #36------------------------------------
# ------------------------------------Extracting Page #37------------------------------------
# ------------------------------------Extracting Page #38------------------------------------
# ------------------------------------Extracting Page #39------------------------------------
# ------------------------------------Extracting Page #40------------------------------------
# ------------------------------------Extracting Page #41------------------------------------
# ------------------------------------Extracting Page #42------------------------------------
# ------------------------------------Extracting Page #43------------------------------------
# ------------------------------------Extracting Page #44------------------------------------
# ------------------------------------Extracting Page #45------------------------------------
# ------------------------------------Extracting Page #46------------------------------------
# ------------------------------------Extracting Page #47------------------------------------
# ------------------------------------Extracting Page #48------------------------------------
# ------------------------------------Extracting Page #49------------------------------------
# ------------------------------------Extracting Page #50------------------------------------
# ------------------------------------Extracting Page #51------------------------------------
# ------------------------------------Extracting Page #52------------------------------------
# ------------------------------------Extracting Page #53------------------------------------
# ------------------------------------Extracting Page #54------------------------------------
# ------------------------------------Extracting Page #55------------------------------------
# ------------------------------------Extracting Page #56------------------------------------
# ------------------------------------Extracting Page #57------------------------------------
# ------------------------------------Extracting Page #58------------------------------------
# ------------------------------------Extracting Page #59------------------------------------
# ------------------------------------Extracting Page #60------------------------------------
# ------------------------------------Extracting Page #61------------------------------------
# ------------------------------------Extracting Page #62------------------------------------
# ------------------------------------Extracting Page #63------------------------------------
# ------------------------------------Extracting Page #64------------------------------------
# ------------------------------------Extracting Page #65------------------------------------
# ------------------------------------Extracting Page #66------------------------------------
# ------------------------------------Extracting Page #67------------------------------------
# ------------------------------------Extracting Page #68------------------------------------
# ------------------------------------Extracting Page #69------------------------------------
# ------------------------------------Extracting Page #70------------------------------------
# ------------------------------------Extracting Page #71------------------------------------
# ------------------------------------Extracting Page #72------------------------------------
# ------------------------------------Extracting Page #73------------------------------------
# ------------------------------------Extracting Page #74------------------------------------
# ------------------------------------Extracting Page #75------------------------------------
# ------------------------------------Extracting Page #76------------------------------------
# ------------------------------------Extracting Page #77------------------------------------
# ------------------------------------Extracting Page #78------------------------------------
# ------------------------------------Extracting Page #79------------------------------------
# ------------------------------------Extracting Page #80------------------------------------
# ------------------------------------Extracting Page #81------------------------------------
# ------------------------------------Extracting Page #82------------------------------------
# ------------------------------------Extracting Page #83------------------------------------
# ------------------------------------Extracting Page #84------------------------------------
# ------------------------------------Extracting Page #85------------------------------------
# ------------------------------------Extracting Page #86------------------------------------
# ------------------------------------Extracting Page #87------------------------------------
# ------------------------------------Extracting Page #88------------------------------------
# ------------------------------------Extracting Page #89------------------------------------
# ------------------------------------Extracting Page #90------------------------------------
# ------------------------------------Extracting Page #91------------------------------------
# ------------------------------------Extracting Page #92------------------------------------
# ------------------------------------Extracting Page #93------------------------------------
# ------------------------------------Extracting Page #94------------------------------------
# ------------------------------------Extracting Page #95------------------------------------
# ------------------------------------Extracting Page #96------------------------------------
# ------------------------------------Extracting Page #97------------------------------------
# ------------------------------------Extracting Page #98------------------------------------
# ------------------------------------Extracting Page #99------------------------------------
# ------------------------------------Extracting Page #100------------------------------------
# ------------------------------------Extracting Page #101------------------------------------
# ------------------------------------Extracting Page #102------------------------------------
# ------------------------------------Extracting Page #103------------------------------------
# ------------------------------------Extracting Page #104------------------------------------
# ------------------------------------Extracting Page #105------------------------------------
# ------------------------------------Extracting Page #106------------------------------------
# ------------------------------------Extracting Page #107------------------------------------
# ------------------------------------Extracting Page #108------------------------------------
# ------------------------------------Extracting Page #109------------------------------------
# ------------------------------------Extracting Page #110------------------------------------
# ------------------------------------Extracting Page #111------------------------------------
# ------------------------------------Extracting Page #112------------------------------------
# ------------------------------------Extracting Page #113------------------------------------
# ------------------------------------Extracting Page #114------------------------------------
# ------------------------------------Extracting Page #115------------------------------------
# ------------------------------------Extracting Page #116------------------------------------
# ------------------------------------Extracting Page #117------------------------------------
# ------------------------------------Extracting Page #118------------------------------------
# ------------------------------------Extracting Page #119------------------------------------
# ------------------------------------Extracting Page #120------------------------------------
# ------------------------------------Extracting Page #121------------------------------------
# ------------------------------------Extracting Page #122------------------------------------
# ------------------------------------Extracting Page #123------------------------------------
# ------------------------------------Extracting Page #124------------------------------------
# ------------------------------------Extracting Page #125------------------------------------
# ------------------------------------Extracting Page #126------------------------------------
# ------------------------------------Extracting Page #127------------------------------------
# ------------------------------------Extracting Page #128------------------------------------
# ------------------------------------Extracting Page #129------------------------------------
# ------------------------------------Extracting Page #130------------------------------------
# ------------------------------------Extracting Page #131------------------------------------
# ------------------------------------Extracting Page #132------------------------------------
# ------------------------------------Extracting Page #133------------------------------------
# ------------------------------------Extracting Page #134------------------------------------
# ------------------------------------Extracting Page #135------------------------------------
# ------------------------------------Extracting Page #136------------------------------------
# ------------------------------------Extracting Page #137------------------------------------
# ------------------------------------Extracting Page #138------------------------------------
# ------------------------------------Extracting Page #139------------------------------------
# ------------------------------------Extracting Page #140------------------------------------
# ------------------------------------Extracting Page #141------------------------------------
# ------------------------------------Extracting Page #142------------------------------------
# ------------------------------------Extracting Page #143------------------------------------
# ------------------------------------Extracting Page #144------------------------------------
# ------------------------------------Extracting Page #145------------------------------------
# ------------------------------------Extracting Page #146------------------------------------
# ------------------------------------Extracting Page #147------------------------------------
# ------------------------------------Extracting Page #148------------------------------------
# ------------------------------------Extracting Page #149------------------------------------
# ------------------------------------Extracting Page #150------------------------------------
# ------------------------------------Extracting Page #151------------------------------------
# ------------------------------------Extracting Page #152------------------------------------
# ------------------------------------Extracting Page #153------------------------------------
# ------------------------------------Extracting Page #154------------------------------------
# ------------------------------------Extracting Page #155------------------------------------
# ------------------------------------Extracting Page #156------------------------------------
# ------------------------------------Extracting Page #157------------------------------------
# ------------------------------------Extracting Page #158------------------------------------
# ------------------------------------Extracting Page #159------------------------------------
# ------------------------------------Extracting Page #160------------------------------------
# ------------------------------------Extracting Page #161------------------------------------
# ------------------------------------Extracting Page #162------------------------------------
# ------------------------------------Extracting Page #163------------------------------------
# ------------------------------------Extracting Page #164------------------------------------
# ------------------------------------Extracting Page #165------------------------------------
# ------------------------------------Extracting Page #166------------------------------------
# ------------------------------------Extracting Page #167------------------------------------
# ------------------------------------Extracting Page #168------------------------------------
# ------------------------------------Extracting Page #169------------------------------------
# ------------------------------------Extracting Page #170------------------------------------
# ------------------------------------Extracting Page #171------------------------------------
# ------------------------------------Extracting Page #172------------------------------------
# ------------------------------------Extracting Page #173------------------------------------
# ------------------------------------Extracting Page #174------------------------------------
# ------------------------------------Extracting Page #175------------------------------------
# ------------------------------------Extracting Page #176------------------------------------
# ------------------------------------Extracting Page #177------------------------------------
# ------------------------------------Extracting Page #178------------------------------------
# ------------------------------------Extracting Page #179------------------------------------
# ------------------------------------Extracting Page #180------------------------------------
# ------------------------------------Extracting Page #181------------------------------------
# ------------------------------------Extracting Page #182------------------------------------
# ------------------------------------Extracting Page #183------------------------------------
# ------------------------------------Extracting Page #184------------------------------------
# ------------------------------------Extracting Page #185------------------------------------
# ------------------------------------Extracting Page #186------------------------------------
# ------------------------------------Extracting Page #187------------------------------------
# ------------------------------------Extracting Page #188------------------------------------
# ------------------------------------Extracting Page #189------------------------------------
# ------------------------------------Extracting Page #190------------------------------------
# ------------------------------------Extracting Page #191------------------------------------
# ------------------------------------Extracting Page #192------------------------------------
# ------------------------------------Extracting Page #193------------------------------------
# ------------------------------------Extracting Page #194------------------------------------
# ------------------------------------Extracting Page #195------------------------------------
# ------------------------------------Extracting Page #196------------------------------------
# ------------------------------------Extracting Page #197------------------------------------
# ------------------------------------Extracting Page #198------------------------------------
# ------------------------------------Extracting Page #199------------------------------------
# ------------------------------------Extracting Page #200------------------------------------
# ------------------------------------Extracting Page #201------------------------------------
# ------------------------------------Extracting Page #202------------------------------------
# ------------------------------------Extracting Page #203------------------------------------
# ------------------------------------Extracting Page #204------------------------------------
# ------------------------------------Extracting Page #205------------------------------------
# ------------------------------------Extracting Page #206------------------------------------
# ------------------------------------Extracting Page #207------------------------------------
# ------------------------------------Extracting Page #208------------------------------------
# ------------------------------------Extracting Page #209------------------------------------
# ------------------------------------Extracting Page #210------------------------------------
# ------------------------------------Extracting Page #211------------------------------------
# ------------------------------------Extracting Page #212------------------------------------
# ------------------------------------Extracting Page #213------------------------------------
# ------------------------------------Extracting Page #214------------------------------------
# ------------------------------------Extracting Page #215------------------------------------
# ------------------------------------Extracting Page #216------------------------------------
# ------------------------------------Extracting Page #217------------------------------------
# ------------------------------------Extracting Page #218------------------------------------
# ------------------------------------Extracting Page #219------------------------------------
# ------------------------------------Extracting Page #220------------------------------------
# ------------------------------------Extracting Page #221------------------------------------
# ------------------------------------Extracting Page #222------------------------------------
# ------------------------------------Extracting Page #223------------------------------------
# ------------------------------------Extracting Page #224------------------------------------
# ------------------------------------Extracting Page #225------------------------------------
# ------------------------------------Extracting Page #226------------------------------------
# ------------------------------------Extracting Page #227------------------------------------
# ------------------------------------Extracting Page #228------------------------------------
# ------------------------------------Extracting Page #229------------------------------------
# ------------------------------------Extracting Page #230------------------------------------
# ------------------------------------Extracting Page #231------------------------------------
# ------------------------------------Extracting Page #232------------------------------------
# ------------------------------------Extracting Page #233------------------------------------
# ------------------------------------Extracting Page #234------------------------------------
# ------------------------------------Extracting Page #235------------------------------------
# ------------------------------------Extracting Page #236------------------------------------
# ------------------------------------Extracting Page #237------------------------------------
# ------------------------------------Extracting Page #238------------------------------------
# ------------------------------------Extracting Page #239------------------------------------
# ------------------------------------Extracting Page #240------------------------------------
# ------------------------------------Extracting Page #241------------------------------------
# ------------------------------------Extracting Page #242------------------------------------
# ------------------------------------Extracting Page #243------------------------------------
# ------------------------------------Extracting Page #244------------------------------------
# ------------------------------------Extracting Page #245------------------------------------
# ------------------------------------Extracting Page #246------------------------------------
# ------------------------------------Extracting Page #247------------------------------------
# ------------------------------------Extracting Page #248------------------------------------
# ------------------------------------Extracting Page #249------------------------------------
# ------------------------------------Extracting Page #250------------------------------------
# ------------------------------------Extracting Page #251------------------------------------
# ------------------------------------Extracting Page #252------------------------------------
# ------------------------------------Extracting Page #253------------------------------------
# ------------------------------------Extracting Page #254------------------------------------
# ------------------------------------Extracting Page #255------------------------------------
# ------------------------------------Extracting Page #256------------------------------------
# ------------------------------------Extracting Page #257------------------------------------
# ------------------------------------Extracting Page #258------------------------------------
# ------------------------------------Extracting Page #259------------------------------------
# ------------------------------------Extracting Page #260------------------------------------
# ------------------------------------Extracting Page #261------------------------------------
# ------------------------------------Extracting Page #262------------------------------------
# ------------------------------------Extracting Page #263------------------------------------
# ------------------------------------Extracting Page #264------------------------------------
# ------------------------------------Extracting Page #265------------------------------------
# ------------------------------------Extracting Page #266------------------------------------
# ------------------------------------Extracting Page #267------------------------------------
# ------------------------------------Extracting Page #268------------------------------------
# ------------------------------------Extracting Page #269------------------------------------
# ------------------------------------Extracting Page #270------------------------------------
# ------------------------------------Extracting Page #271------------------------------------
# ------------------------------------Extracting Page #272------------------------------------
# ------------------------------------Extracting Page #273------------------------------------
# ------------------------------------Extracting Page #274------------------------------------
# ------------------------------------Extracting Page #275------------------------------------
# ------------------------------------Extracting Page #276------------------------------------
# ------------------------------------Extracting Page #277------------------------------------
# ------------------------------------Extracting Page #278------------------------------------
# ------------------------------------Extracting Page #279------------------------------------
# ------------------------------------Extracting Page #280------------------------------------
# ------------------------------------Extracting Page #281------------------------------------
# ------------------------------------Extracting Page #282------------------------------------
# ------------------------------------Extracting Page #283------------------------------------
# ------------------------------------Extracting Page #284------------------------------------
# ------------------------------------Extracting Page #285------------------------------------
# ------------------------------------Extracting Page #286------------------------------------
# ------------------------------------Extracting Page #287------------------------------------
# ------------------------------------Extracting Page #288------------------------------------
# ------------------------------------Extracting Page #289------------------------------------
# ------------------------------------Extracting Page #290------------------------------------
# ------------------------------------Extracting Page #291------------------------------------
# ------------------------------------Extracting Page #292------------------------------------
# ------------------------------------Extracting Page #293------------------------------------
# ------------------------------------Extracting Page #294------------------------------------
# ------------------------------------Extracting Page #295------------------------------------
# ------------------------------------Extracting Page #296------------------------------------
# ------------------------------------Extracting Page #297------------------------------------
# ------------------------------------Extracting Page #298------------------------------------
# ------------------------------------Extracting Page #299------------------------------------
# ------------------------------------Extracting Page #300------------------------------------
# ------------------------------------Extracting Page #301------------------------------------
# ------------------------------------Extracting Page #302------------------------------------
# ------------------------------------Extracting Page #303------------------------------------
# ------------------------------------Extracting Page #304------------------------------------
# ------------------------------------Extracting Page #305------------------------------------
# ------------------------------------Extracting Page #306------------------------------------
# ------------------------------------Extracting Page #307------------------------------------
# ------------------------------------Extracting Page #308------------------------------------
# ------------------------------------Extracting Page #309------------------------------------
# ------------------------------------Extracting Page #310------------------------------------
# ------------------------------------Extracting Page #311------------------------------------
# ------------------------------------Extracting Page #312------------------------------------
# ------------------------------------Extracting Page #313------------------------------------
# ------------------------------------Extracting Page #314------------------------------------
# ------------------------------------Extracting Page #315------------------------------------
# ------------------------------------Extracting Page #316------------------------------------
# ------------------------------------Extracting Page #317------------------------------------
# ------------------------------------Extracting Page #318------------------------------------
# ------------------------------------Extracting Page #319------------------------------------
# ------------------------------------Extracting Page #320------------------------------------
# ------------------------------------Extracting Page #321------------------------------------
# ------------------------------------Extracting Page #322------------------------------------
# ------------------------------------Extracting Page #323------------------------------------
# ------------------------------------Extracting Page #324------------------------------------
# ------------------------------------Extracting Page #325------------------------------------
# ------------------------------------Extracting Page #326------------------------------------
# ------------------------------------Extracting Page #327------------------------------------
# ------------------------------------Extracting Page #328------------------------------------
# ------------------------------------Extracting Page #329------------------------------------
# ------------------------------------Extracting Page #330------------------------------------
# ------------------------------------Extracting Page #331------------------------------------
# ------------------------------------Extracting Page #332------------------------------------
# ------------------------------------Extracting Page #333------------------------------------
# ------------------------------------Extracting Page #334------------------------------------
# ------------------------------------Extracting Page #335------------------------------------
# ------------------------------------Extracting Page #336------------------------------------
# ------------------------------------Extracting Page #337------------------------------------
# ------------------------------------Extracting Page #338------------------------------------
# ------------------------------------Extracting Page #339------------------------------------
# ------------------------------------Extracting Page #340------------------------------------
# ------------------------------------Extracting Page #341------------------------------------
# ------------------------------------Extracting Page #342------------------------------------
# ------------------------------------Extracting Page #343------------------------------------
# ------------------------------------Extracting Page #344------------------------------------
# ------------------------------------Extracting Page #345------------------------------------
# ------------------------------------Extracting Page #346------------------------------------
# ------------------------------------Extracting Page #347------------------------------------
# ------------------------------------Extracting Page #348------------------------------------
# ------------------------------------Extracting Page #349------------------------------------
# ------------------------------------Extracting Page #350------------------------------------
# ------------------------------------Extracting Page #351------------------------------------
# ------------------------------------Extracting Page #352------------------------------------
# ------------------------------------Extracting Page #353------------------------------------
# ------------------------------------Extracting Page #354------------------------------------
# ------------------------------------Extracting Page #355------------------------------------
# ------------------------------------Extracting Page #356------------------------------------
# ------------------------------------Extracting Page #357------------------------------------
# ------------------------------------Extracting Page #358------------------------------------
# ------------------------------------Extracting Page #359------------------------------------
# ------------------------------------Extracting Page #360------------------------------------
# ------------------------------------Extracting Page #361------------------------------------
# ------------------------------------Extracting Page #362------------------------------------
# ------------------------------------Extracting Page #363------------------------------------
# ------------------------------------Extracting Page #364------------------------------------
# ------------------------------------Extracting Page #365------------------------------------
# ------------------------------------Extracting Page #366------------------------------------
# ------------------------------------Extracting Page #367------------------------------------
# ------------------------------------Extracting Page #368------------------------------------
# ------------------------------------Extracting Page #369------------------------------------
# ------------------------------------Extracting Page #370------------------------------------
# ------------------------------------Extracting Page #371------------------------------------
# ------------------------------------Extracting Page #372------------------------------------
# ------------------------------------Extracting Page #373------------------------------------
# ------------------------------------Extracting Page #374------------------------------------
# ------------------------------------Extracting Page #375------------------------------------
# ------------------------------------Extracting Page #376------------------------------------
# ------------------------------------Extracting Page #377------------------------------------
# ------------------------------------Extracting Page #378------------------------------------
# ------------------------------------Extracting Page #379------------------------------------
# ------------------------------------Extracting Page #380------------------------------------
# ------------------------------------Extracting Page #381------------------------------------
# ------------------------------------Extracting Page #382------------------------------------
# ------------------------------------Extracting Page #383------------------------------------
# ------------------------------------Extracting Page #384------------------------------------
# ------------------------------------Extracting Page #385------------------------------------
# ------------------------------------Extracting Page #386------------------------------------
# ------------------------------------Extracting Page #387------------------------------------
# ------------------------------------Extracting Page #388------------------------------------
# ------------------------------------Extracting Page #389------------------------------------
# ------------------------------------Extracting Page #390------------------------------------
# ------------------------------------Extracting Page #391------------------------------------
# ------------------------------------Extracting Page #392------------------------------------
# ------------------------------------Extracting Page #393------------------------------------
# ------------------------------------Extracting Page #394------------------------------------
# ------------------------------------Extracting Page #395------------------------------------
# ------------------------------------Extracting Page #396------------------------------------
# ------------------------------------Extracting Page #397------------------------------------
# ------------------------------------Extracting Page #398------------------------------------
# ------------------------------------Extracting Page #399------------------------------------
# ------------------------------------Extracting Page #400------------------------------------
# ------------------------------------Extracting Page #401------------------------------------
# ------------------------------------Extracting Page #402------------------------------------
# ------------------------------------Extracting Page #403------------------------------------
# ------------------------------------Extracting Page #404------------------------------------
# ------------------------------------Extracting Page #405------------------------------------
# ------------------------------------Extracting Page #406------------------------------------
# ------------------------------------Extracting Page #407------------------------------------
# ------------------------------------Extracting Page #408------------------------------------
# ------------------------------------Extracting Page #409------------------------------------
# ------------------------------------Extracting Page #410------------------------------------
# ------------------------------------Extracting Page #411------------------------------------
# ------------------------------------Extracting Page #412------------------------------------
# ------------------------------------Extracting Page #413------------------------------------
# ------------------------------------Extracting Page #414------------------------------------
# ------------------------------------Extracting Page #415------------------------------------
# ------------------------------------Extracting Page #416------------------------------------
# ------------------------------------Extracting Page #417------------------------------------
# ------------------------------------Extracting Page #418------------------------------------
# ------------------------------------Extracting Page #419------------------------------------
# ------------------------------------Extracting Page #420------------------------------------
# ------------------------------------Extracting Page #421------------------------------------
# ------------------------------------Extracting Page #422------------------------------------
# ------------------------------------Extracting Page #423------------------------------------
# ------------------------------------Extracting Page #424------------------------------------
# ------------------------------------Extracting Page #425------------------------------------
# ------------------------------------Extracting Page #426------------------------------------
# ------------------------------------Extracting Page #427------------------------------------
# ------------------------------------Extracting Page #428------------------------------------
# ------------------------------------Extracting Page #429------------------------------------
# ------------------------------------Extracting Page #430------------------------------------
# ------------------------------------Extracting Page #431------------------------------------
# ------------------------------------Extracting Page #432------------------------------------
# ------------------------------------Extracting Page #433------------------------------------
# ------------------------------------Extracting Page #434------------------------------------
# ------------------------------------Extracting Page #435------------------------------------
# ------------------------------------Extracting Page #436------------------------------------
# ------------------------------------Extracting Page #437------------------------------------
# ------------------------------------Extracting Page #438------------------------------------
# ------------------------------------Extracting Page #439------------------------------------
# ------------------------------------Extracting Page #440------------------------------------
# ------------------------------------Extracting Page #441------------------------------------
# ------------------------------------Extracting Page #442------------------------------------
# ------------------------------------Extracting Page #443------------------------------------
# ------------------------------------Extracting Page #444------------------------------------
# ------------------------------------Extracting Page #445------------------------------------
# ------------------------------------Extracting Page #446------------------------------------
# ------------------------------------Extracting Page #447------------------------------------
# ------------------------------------Extracting Page #448------------------------------------
# ------------------------------------Extracting Page #449------------------------------------
# ------------------------------------Extracting Page #450------------------------------------
# ------------------------------------Extracting Page #451------------------------------------
# ------------------------------------Extracting Page #452------------------------------------
# ------------------------------------Extracting Page #453------------------------------------
# ------------------------------------Extracting Page #454------------------------------------
# ------------------------------------Extracting Page #455------------------------------------
# ------------------------------------Extracting Page #456------------------------------------
# ------------------------------------Extracting Page #457------------------------------------
# ------------------------------------Extracting Page #458------------------------------------
# ------------------------------------Extracting Page #459------------------------------------
# ------------------------------------Extracting Page #460------------------------------------
# ------------------------------------Extracting Page #461------------------------------------
# ------------------------------------Extracting Page #462------------------------------------
# ------------------------------------Extracting Page #463------------------------------------
# ------------------------------------Extracting Page #464------------------------------------
# ------------------------------------Extracting Page #465------------------------------------
# ------------------------------------Extracting Page #466------------------------------------
# ------------------------------------Extracting Page #467------------------------------------
# ------------------------------------Extracting Page #468------------------------------------
# ------------------------------------Extracting Page #469------------------------------------
# ------------------------------------Extracting Page #470------------------------------------
# ------------------------------------Extracting Page #471------------------------------------
# ------------------------------------Extracting Page #472------------------------------------
# ------------------------------------Extracting Page #473------------------------------------
# ------------------------------------Extracting Page #474------------------------------------
# ------------------------------------Extracting Page #475------------------------------------
# ------------------------------------Extracting Page #476------------------------------------
# ------------------------------------Extracting Page #477------------------------------------
# ------------------------------------Extracting Page #478------------------------------------
# ------------------------------------Extracting Page #479------------------------------------
# ------------------------------------Extracting Page #480------------------------------------
# ------------------------------------Extracting Page #481------------------------------------
# ------------------------------------Extracting Page #482------------------------------------
# ------------------------------------Extracting Page #483------------------------------------
# ------------------------------------Extracting Page #484------------------------------------
# ------------------------------------Extracting Page #485------------------------------------
# ------------------------------------Extracting Page #486------------------------------------
# ------------------------------------Extracting Page #487------------------------------------
# ------------------------------------Extracting Page #488------------------------------------
# ------------------------------------Extracting Page #489------------------------------------
# ------------------------------------Extracting Page #490------------------------------------
# ------------------------------------Extracting Page #491------------------------------------
# ------------------------------------Extracting Page #492------------------------------------
# ------------------------------------Extracting Page #493------------------------------------
# ------------------------------------Extracting Page #494------------------------------------
# ------------------------------------Extracting Page #495------------------------------------
# ------------------------------------Extracting Page #496------------------------------------
# ------------------------------------Extracting Page #497------------------------------------
# ------------------------------------Extracting Page #498------------------------------------
# ------------------------------------Extracting Page #499------------------------------------
# ------------------------------------Extracting Page #500------------------------------------
# ------------------------------------Extracting Page #501------------------------------------
# ------------------------------------Extracting Page #502------------------------------------
# ------------------------------------Extracting Page #503------------------------------------
# ------------------------------------Extracting Page #504------------------------------------
# ------------------------------------Extracting Page #505------------------------------------
# ------------------------------------Extracting Page #506------------------------------------
# ------------------------------------Extracting Page #507------------------------------------
# ------------------------------------Extracting Page #508------------------------------------
# ------------------------------------Extracting Page #509------------------------------------
# ------------------------------------Extracting Page #510------------------------------------
# ------------------------------------Extracting Page #511------------------------------------
# ------------------------------------Extracting Page #512------------------------------------
# ------------------------------------Extracting Page #513------------------------------------
# ------------------------------------Extracting Page #514------------------------------------
# ------------------------------------Extracting Page #515------------------------------------
# ------------------------------------Extracting Page #516------------------------------------
# ------------------------------------Extracting Page #517------------------------------------
# ...
# ------------------------------------Extracting Page #828------------------------------------
# ------------------------------------Extracting Page #829------------------------------------
# ------------------------------------Extracting Page #830------------------------------------
# ------------------------------------Extracting Page #831------------------------------------
# ------------------------------------Extracting Page #832------------------------------------
# ------------------------------------Extracting Page #833------------------------------------
# ------------------------------------Extracting Page #834------------------------------------
# ------------------------------------Extracting Page #835------------------------------------
# ------------------------------------Extracting Page #836------------------------------------
# ------------------------------------Extracting Page #837------------------------------------
# ------------------------------------Extracting Page #838------------------------------------
# ------------------------------------Extracting Page #839------------------------------------
# ------------------------------------Extracting Page #840------------------------------------
# ------------------------------------Extracting Page #841------------------------------------
# ------------------------------------Extracting Page #842------------------------------------
# ------------------------------------Extracting Page #843------------------------------------
# ------------------------------------Extracting Page #844------------------------------------
# ------------------------------------Extracting Page #845------------------------------------
# ------------------------------------Extracting Page #846------------------------------------
# ------------------------------------Extracting Page #847------------------------------------
# ------------------------------------Extracting Page #848------------------------------------
# ------------------------------------Extracting Page #849------------------------------------
# ------------------------------------Extracting Page #850------------------------------------
# ------------------------------------Extracting Page #851------------------------------------
# ------------------------------------Extracting Page #852------------------------------------
# ------------------------------------Extracting Page #853------------------------------------
# ------------------------------------Extracting Page #854------------------------------------
# ------------------------------------Extracting Page #855------------------------------------
# ------------------------------------Extracting Page #856------------------------------------
# ------------------------------------Extracting Page #857------------------------------------
# ------------------------------------Extracting Page #858------------------------------------
# ------------------------------------Extracting Page #859------------------------------------
# ------------------------------------Extracting Page #860------------------------------------
# ------------------------------------Extracting Page #861------------------------------------
# ------------------------------------Extracting Page #862------------------------------------
# ------------------------------------Extracting Page #863------------------------------------
# ------------------------------------Extracting Page #864------------------------------------
# ------------------------------------Extracting Page #865------------------------------------
# ------------------------------------Extracting Page #866------------------------------------
# ------------------------------------Extracting Page #867------------------------------------
# ------------------------------------Extracting Page #868------------------------------------
# ------------------------------------Extracting Page #869------------------------------------
# ------------------------------------Extracting Page #870------------------------------------
# ------------------------------------Extracting Page #871------------------------------------
# ------------------------------------Extracting Page #872------------------------------------
# ------------------------------------Extracting Page #873------------------------------------
# ------------------------------------Extracting Page #874------------------------------------
# ------------------------------------Extracting Page #875------------------------------------
# ------------------------------------Extracting Page #876------------------------------------
# ------------------------------------Extracting Page #877------------------------------------
# ------------------------------------Extracting Page #878------------------------------------
# ------------------------------------Extracting Page #879------------------------------------
# ------------------------------------Extracting Page #880------------------------------------
# ------------------------------------Extracting Page #881------------------------------------
# ------------------------------------Extracting Page #882------------------------------------
# ------------------------------------Extracting Page #883------------------------------------
# ------------------------------------Extracting Page #884------------------------------------
# ------------------------------------Extracting Page #885------------------------------------
# ------------------------------------Extracting Page #886------------------------------------
# ------------------------------------Extracting Page #887------------------------------------
# ------------------------------------Extracting Page #888------------------------------------
# ------------------------------------Extracting Page #889------------------------------------
# ------------------------------------Extracting Page #890------------------------------------
# ------------------------------------Extracting Page #891------------------------------------
# ------------------------------------Extracting Page #892------------------------------------
# ------------------------------------Extracting Page #893------------------------------------
# ------------------------------------Extracting Page #894------------------------------------
# ------------------------------------Extracting Page #895------------------------------------
# ------------------------------------Extracting Page #896------------------------------------
# ------------------------------------Extracting Page #897------------------------------------
# ------------------------------------Extracting Page #898------------------------------------
# ------------------------------------Extracting Page #899------------------------------------
# ------------------------------------Extracting Page #900------------------------------------
# ------------------------------------Extracting Page #901------------------------------------
# ------------------------------------Extracting Page #902------------------------------------
# ------------------------------------Extracting Page #903------------------------------------
# ------------------------------------Extracting Page #904------------------------------------
# ------------------------------------Extracting Page #905------------------------------------
# ------------------------------------Extracting Page #906------------------------------------
# ------------------------------------Extracting Page #907------------------------------------
# ------------------------------------Extracting Page #908------------------------------------
# ------------------------------------Extracting Page #909------------------------------------
# ------------------------------------Extracting Page #910------------------------------------
# ------------------------------------Extracting Page #911------------------------------------
# ------------------------------------Extracting Page #912------------------------------------
# ------------------------------------Extracting Page #913------------------------------------
# ------------------------------------Extracting Page #914------------------------------------
# ------------------------------------Extracting Page #915------------------------------------
# ------------------------------------Extracting Page #916------------------------------------
# ------------------------------------Extracting Page #917------------------------------------
# ------------------------------------Extracting Page #918------------------------------------
# ------------------------------------Extracting Page #919------------------------------------
# ------------------------------------Extracting Page #920------------------------------------
# ------------------------------------Extracting Page #921------------------------------------
# ------------------------------------Extracting Page #922------------------------------------
# ------------------------------------Extracting Page #923------------------------------------
# ------------------------------------Extracting Page #924------------------------------------
# ------------------------------------Extracting Page #925------------------------------------
# ------------------------------------Extracting Page #926------------------------------------
# ------------------------------------Extracting Page #927------------------------------------
# ------------------------------------Extracting Page #928------------------------------------
# ------------------------------------Extracting Page #929------------------------------------
# ------------------------------------Extracting Page #930------------------------------------
# ------------------------------------Extracting Page #931------------------------------------
# ------------------------------------Extracting Page #932------------------------------------
# ------------------------------------Extracting Page #933------------------------------------
# ------------------------------------Extracting Page #934------------------------------------
# ------------------------------------Extracting Page #935------------------------------------
# ------------------------------------Extracting Page #936------------------------------------
# ------------------------------------Extracting Page #937------------------------------------
# ------------------------------------Extracting Page #938------------------------------------
# ------------------------------------Extracting Page #939------------------------------------
# ------------------------------------Extracting Page #940------------------------------------
# ------------------------------------Extracting Page #941------------------------------------
# ------------------------------------Extracting Page #942------------------------------------
# ------------------------------------Extracting Page #943------------------------------------
# ------------------------------------Extracting Page #944------------------------------------
# ------------------------------------Extracting Page #945------------------------------------
# ------------------------------------Extracting Page #946------------------------------------
# ------------------------------------Extracting Page #947------------------------------------
# ------------------------------------Extracting Page #948------------------------------------
# ------------------------------------Extracting Page #949------------------------------------
# ------------------------------------Extracting Page #950------------------------------------
# ------------------------------------Extracting Page #951------------------------------------
# ------------------------------------Extracting Page #952------------------------------------
# ------------------------------------Extracting Page #953------------------------------------
# ------------------------------------Extracting Page #954------------------------------------
# ------------------------------------Extracting Page #955------------------------------------
# ------------------------------------Extracting Page #956------------------------------------
# ------------------------------------Extracting Page #957------------------------------------
# ------------------------------------Extracting Page #958------------------------------------
# ------------------------------------Extracting Page #959------------------------------------
# ------------------------------------Extracting Page #960------------------------------------
# ------------------------------------Extracting Page #961------------------------------------
# ------------------------------------Extracting Page #962------------------------------------
# ------------------------------------Extracting Page #963------------------------------------
# ------------------------------------Extracting Page #964------------------------------------
# ------------------------------------Extracting Page #965------------------------------------
# ------------------------------------Extracting Page #966------------------------------------
# ------------------------------------Extracting Page #967------------------------------------
# ------------------------------------Extracting Page #968------------------------------------
# ------------------------------------Extracting Page #969------------------------------------
# ------------------------------------Extracting Page #970------------------------------------
# ------------------------------------Extracting Page #971------------------------------------
# ------------------------------------Extracting Page #972------------------------------------
# ------------------------------------Extracting Page #973------------------------------------
# ------------------------------------Extracting Page #974------------------------------------
# ------------------------------------Extracting Page #975------------------------------------
# ------------------------------------Extracting Page #976------------------------------------
# ------------------------------------Extracting Page #977------------------------------------
# ------------------------------------Extracting Page #978------------------------------------
# ------------------------------------Extracting Page #979------------------------------------
# ------------------------------------Extracting Page #980------------------------------------
# ------------------------------------Extracting Page #981------------------------------------
# ------------------------------------Extracting Page #982------------------------------------
# ------------------------------------Extracting Page #983------------------------------------
# ------------------------------------Extracting Page #984------------------------------------
# ------------------------------------Extracting Page #985------------------------------------
# ------------------------------------Extracting Page #986------------------------------------
# ------------------------------------Extracting Page #987------------------------------------
# ------------------------------------Extracting Page #988------------------------------------
# ------------------------------------Extracting Page #989------------------------------------
# ------------------------------------Extracting Page #990------------------------------------
# ------------------------------------Extracting Page #991------------------------------------
# ------------------------------------Extracting Page #992------------------------------------
# ------------------------------------Extracting Page #993------------------------------------
# ------------------------------------Extracting Page #994------------------------------------
# ------------------------------------Extracting Page #995------------------------------------
# ------------------------------------Extracting Page #996------------------------------------
# ------------------------------------Extracting Page #997------------------------------------
# ------------------------------------Extracting Page #998------------------------------------
# ------------------------------------Extracting Page #999------------------------------------

# %%
print(request.keys())
print(request)
# Out:
# dict_keys(['message'])
# {'message': 'Too Many Requests'}

# %% [markdown]
# Question 4: Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.(10 points)
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
Df = pd.read_csv('twitter_tweets.csv')

# %%
cols = ['user_name', 'date','text']

# %%
print(Df.head())
# Out:
#          user_name         user_location  \
# 0           ᏉᎥ☻լꂅϮ            astroworld
# 1    Tom Basile 🇺🇸          New York, NY
# 2  Time4fisticuffs      Pewee Valley, KY
# 3      ethel mertz  Stuck in the Middle
# 4         DIPR-J&K     Jammu and Kashmir
#
#                                     user_description         user_created  \
# 0  wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1  Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2  #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3  #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4  🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
#
#    user_followers  user_friends  user_favourites  user_verified  \
# 0             624           950            18775          False
# 1            2253          1677               24           True
# 2            9275          9525             7254          False
# 3             197           987             1488          False
# 4          101009           168              101          False
#
#                   date                                               text  \
# 0  2020-07-25 12:27:21  If I smelled the scent of hand sanitizers toda...
# 1  2020-07-25 12:27:17  Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 2  2020-07-25 12:27:14  @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 3  2020-07-25 12:27:10  @brookbanktv The one gift #COVID19 has give me...
# 4  2020-07-25 12:27:08  25 July : Media Bulletin on Novel #CoronaVirus...
#
#                             hashtags               source  is_retweet
# 0                                NaN   Twitter for iPhone       False
# 1                                NaN  Twitter for Android       False
# 2                        ['COVID19']  Twitter for Android       False
# 3                        ['COVID19']   Twitter for iPhone       False
# 4  ['CoronaVirusUpdates', 'COVID19']  Twitter for Android       False

# %%
print(Df.columns)
# Out:
# Index(['user_name', 'user_location', 'user_description', 'user_created',
#        'user_followers', 'user_friends', 'user_favourites', 'user_verified',
#        'date', 'text', 'hashtags', 'source', 'is_retweet'],
#       dtype='object')

# %%
Df_filtered = Df.iloc[:1000][cols]

# %%
print(Df_filtered)
# Out:
#                   user_name                 date  \
# 0                    ᏉᎥ☻լꂅϮ  2020-07-25 12:27:21
# 1             Tom Basile 🇺🇸  2020-07-25 12:27:17
# 2           Time4fisticuffs  2020-07-25 12:27:14
# 3               ethel mertz  2020-07-25 12:27:10
# 4                  DIPR-J&K  2020-07-25 12:27:08
# ..                      ...                  ...
# 995                    elKa  2020-07-25 11:58:54
# 996             Bitchrollss  2020-07-25 11:58:49
# 997          Saito Section9  2020-07-25 11:58:47
# 998       ALASIRI MOTORS 🇰🇪  2020-07-25 11:58:47
# 999  Telangana Fights COVID  2020-07-25 11:58:46
#
#                                                   text
# 0    If I smelled the scent of hand sanitizers toda...
# 1    Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 2    @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 3    @brookbanktv The one gift #COVID19 has give me...
# 4    25 July : Media Bulletin on Novel #CoronaVirus...
# ..                                                 ...
# 995  @CassieCeleste @lobster_nanny I do understand....
# 996  My job isn’t to enlighten you #fuck #alreadyvi...
# 997  #COVID19 reflection in a street art, #Kharkiv,...
# 998  Nice Read.\n@MoriangoJr @AdanZamuh @kunga_ @mo...
# 999  Treat every single decision you take regarding...
#
# [1000 rows x 3 columns]
